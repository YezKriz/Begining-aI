# %%
FreeText = [
    "Python is a programming language that lets you work quickly and integrate systems more effectively.", 
    "Streamlit is used to build web apps for machine learning and data science.", 
    "Langchain is a framework for building applications with LLMs.", 
    "RAG combines the power of LLMs with external knowledge sources to provide more accurate and relevant responses.", 
    "Embeddings are numerical representations of text that capture its semantic meaning.",
    "Vector databases are used to store and search embeddings efficiently.", 
    "Dogs are friendly animals"
    "Cats are independent animals"
    "cows are farm animals"
    ]

# %%
#free local embedding model 

from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
# STORE THE TEXT IN FAISS 

vector_Store = FAISS.from_texts(FreeText, embeddings)

print("All free texts are stored in the vector store")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 from langchain_community.vectorstores import FAISS
#       2
# ----> 3 vector_Store = FAISS.from_texts(FreeText, embeddings)
#       4
#       5 print("All free texts are stored in the vector store. Now you can search for any text and it will return the most relevant results based on meaning.")
#
# NameError: name 'FreeText' is not defined

# %%
# A vector store is a special database that saves embeddings (the number vectors that represent text)
#It lets us search by meaning very quickly. This is 4th step in RAG app, RAG means retriveal-augmented generation.

#for example: if you search for CAR Vector store will return results related to CAR, like CAR model, CAR color, CAR price, 

#Install a free vector store (FAISS) pip install faiss-cpu

# %%
#Using openAi embeddings (Optional)
if in case higher quality (paid) embeddings? Use OpenAI embeddings instead of local embeddings. You will need an OpenAI API key for this.

from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small", openai_api_key="your-api-key")

#Faiss doesnot care which embedding model mad the vectors, everything below (storing and searching) stays exact same.
#The only difference is the quality of the embeddings, which will affect the quality of the search results.
